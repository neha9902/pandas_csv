# %% [markdown]
# # # CSV File

# %%
import pandas as pd
import numpy as np

# %%
dataset = pd.read_csv("Sample1000.csv")

# %%
dataset
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
dataset.head(5)
# Out:
#    Serial Number               Company Name  Employee Markme  \
# 0  9788189999599             TALES OF SHIVA             Mark
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                   MY KUMAN             Mark
# 3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
dataset.tail(5)
# Out:
#      Serial Number                      Company Name Employee Markme  \
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS            Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE     Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA            Mark
# 997  9789350891896                MENTAL MATHEMATICS            Mark
# 998  9789383182008            MATHEMATICS CLASS 10th     R.D. SHARMA
#
#                             Description  Leave
# 994  DEEPAK SERIES FOR TEST PREPARATION      0
# 995                         Definitions      0
# 996                          DEREAMLAND      0
# 997                          DEREAMLAND      0
# 998                     DHANPAT RAI &CO      5

# %%
dataset.size
# Out:
# 4995

# %%
dataset.shape
# Out:
# (999, 5)

# %%
data_xls = pd.read_excel("pokemon_data.xlsx")

# %%
data_xls
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dataset = pd.read_csv("Sample1000.csv", delimiter="\t")

# %%
dataset
# Out:
#     Serial Number,Company Name,Employee Markme,Description,Leave
# 0             9788189999599,TALES OF SHIVA,Mark,mark,0
# 1    9780099578079,1Q84 THE COMPLETE TRILOGY,HARUKI...
# 2                   9780198082897,MY KUMAN,Mark,Mark,0
# 3    9780007880331,THE GOD OF SMAAL THINGS,ARUNDHAT...
# 4    9780545060455,THE BLACK CIRCLE,Mark,4TH HARPER...
# ..                                                 ...
# 994  9788192778792,CURRENT AFFAIRS 49 PRACTICE SETS...
# 995  9781862305274,BOY IN THE STRIPED PYJAMAS  THE,...
# 996  9781730155116,SHRI KRISHMark LEELA,Mark,DEREAM...
# 997  9789350891896,MENTAL MATHEMATICS,Mark,DEREAMLA...
# 998  9789383182008,MATHEMATICS CLASS 10th,R.D. SHAR...
#
# [999 rows x 1 columns]

# %%
dataset = pd.read_csv("Sample1000.csv")

# %%
dataset
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
dataset = pd.read_csv("Sample1000.csv", delimiter="ttt")
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_46272\3943606056.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   dataset = pd.read_csv("Sample1000.csv", delimiter="ttt")

# %%
dataset
# Out:
#     Serial Number,Company Name,Employee Markme,Description,Leave
# 0             9788189999599,TALES OF SHIVA,Mark,mark,0
# 1    9780099578079,1Q84 THE COMPLETE TRILOGY,HARUKI...
# 2                   9780198082897,MY KUMAN,Mark,Mark,0
# 3    9780007880331,THE GOD OF SMAAL THINGS,ARUNDHAT...
# 4    9780545060455,THE BLACK CIRCLE,Mark,4TH HARPER...
# ..                                                 ...
# 994  9788192778792,CURRENT AFFAIRS 49 PRACTICE SETS...
# 995  9781862305274,BOY IN THE STRIPED PYJAMAS  THE,...
# 996  9781730155116,SHRI KRISHMark LEELA,Mark,DEREAM...
# 997  9789350891896,MENTAL MATHEMATICS,Mark,DEREAMLA...
# 998  9789383182008,MATHEMATICS CLASS 10th,R.D. SHAR...
#
# [999 rows x 1 columns]

# %%
# Out:
#     Serial Number,Company Name,Employee Markme,Description,Leave
# 0             9788189999599,TALES OF SHIVA,Mark,mark,0
# 1    9780099578079,1Q84 THE COMPLETE TRILOGY,HARUKI...
# 2                   9780198082897,MY KUMAN,Mark,Mark,0
# 3    9780007880331,THE GOD OF SMAAL THINGS,ARUNDHAT...
# 4    9780545060455,THE BLACK CIRCLE,Mark,4TH HARPER...
# ..                                                 ...
# 994  9788192778792,CURRENT AFFAIRS 49 PRACTICE SETS...
# 995  9781862305274,BOY IN THE STRIPED PYJAMAS  THE,...
# 996  9781730155116,SHRI KRISHMark LEELA,Mark,DEREAM...
# 997  9789350891896,MENTAL MATHEMATICS,Mark,DEREAMLA...
# 998  9789383182008,MATHEMATICS CLASS 10th,R.D. SHAR...
#
# [999 rows x 1 columns]

# %%
dataset = pd.read_csv("Sample1000.csv")

# %% [markdown]
# # Reading Data in Pandas

# %%
dataset.columns
# Out:
# Index(['Serial Number', 'Company Name', 'Employee Markme', 'Description',
#        'Leave'],
#       dtype='object')

# %%
dataset['Serial Number']
# Out:
# 0      9788189999599
# 1      9780099578079
# 2      9780198082897
# 3      9780007880331
# 4      9780545060455
#            ...
# 994    9788192778792
# 995    9781862305274
# 996    9781730155116
# 997    9789350891896
# 998    9789383182008
# Name: Serial Number, Length: 999, dtype: int64

# %%
dataset['Serial Number'].head(5)
# Out:
# 0    9788189999599
# 1    9780099578079
# 2    9780198082897
# 3    9780007880331
# 4    9780545060455
# Name: Serial Number, dtype: int64

# %%
dataset.Description
# Out:
# 0                                    mark
# 1                                    Mark
# 2                                    Mark
# 3                      4TH HARPER COLLINS
# 4                      4TH HARPER COLLINS
#                       ...
# 994    DEEPAK SERIES FOR TEST PREPARATION
# 995                           Definitions
# 996                            DEREAMLAND
# 997                            DEREAMLAND
# 998                       DHANPAT RAI &CO
# Name: Description, Length: 999, dtype: object

# %%
dataset[['Serial Number', 'Company Name', 'Employee Markme']]
# Out:
#      Serial Number                      Company Name  Employee Markme
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
# [999 rows x 3 columns]

# %%
dataset.iloc[1]
# Out:
# Serial Number                  9780099578079
# Company Name       1Q84 THE COMPLETE TRILOGY
# Employee Markme              HARUKI MURAKAMI
# Description                             Mark
# Leave                                      0
# Name: 1, dtype: object

# %%
dataset.head(5)
# Out:
#    Serial Number               Company Name  Employee Markme  \
# 0  9788189999599             TALES OF SHIVA             Mark
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                   MY KUMAN             Mark
# 3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave
# 0                mark      0
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0

# %%
dataset.iloc[1:7]
# Out:
#    Serial Number                   Company Name  Employee Markme  \
# 1  9780099578079      1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                       MY KUMAN             Mark
# 3  9780007880331        THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455               THE BLACK CIRCLE             Mark
# 5  9788126525072  THE THREE LAWS OF PERFORMANCE             Mark
# 6  9789381626610              CHAMarkKYA MANTRA             Mark
#
#           Description  Leave
# 1                Mark      0
# 2                Mark      0
# 3  4TH HARPER COLLINS      2
# 4  4TH HARPER COLLINS      0
# 5  4TH HARPER COLLINS      0
# 6  4TH HARPER COLLINS      0

# %%
dataset.iloc[1,3]
# Out:
# 'Mark'

# %%
for index, row in dataset.iterrows():
    print(index, row['Serial Number'])
    if(index==5):
        break
# Out:
# 0 9788189999599
# 1 9780099578079
# 2 9780198082897
# 3 9780007880331
# 4 9780545060455
# 5 9788126525072

# %%
dataset.loc[dataset['Description']=="mark"]
# Out:
#    Serial Number    Company Name Employee Markme Description  Leave
# 0  9788189999599  TALES OF SHIVA            Mark        mark      0

# %%
dataset.loc[dataset['Description']=="Mark"]
# Out:
#    Serial Number               Company Name  Employee Markme Description  \
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI        Mark
# 2  9780198082897                   MY KUMAN             Mark        Mark
#
#    Leave
# 1      0
# 2      0

# %% [markdown]
# # Sorting / Describing data

# %%
dataset.describe()
# Out:
#        Serial Number       Leave
# count   9.990000e+02  999.000000
# mean    9.649954e+12    0.971972
# std     1.150065e+12    2.198381
# min     8.170110e+09    0.000000
# 25%     9.788127e+12    0.000000
# 50%     9.788188e+12    0.000000
# 75%     9.789383e+12    1.000000
# max     9.798170e+12   10.000000

# %%
dataset.sort_values('Serial Number')
# Out:
#      Serial Number                        Company Name Employee Markme  \
# 861     8170110122         PANCHATANTRA KI KAHANIYAN-1             NaN
# 862     8170110335         PANCHATANTRA KI KAHANIYAN-2             NaN
# 863     8170110580         PANCHATANTRA KI KAHANIYAN-3             NaN
# 864     8170110904         PANCHATANTRA KI KAHANIYAN-4             NaN
# 865     8170112311   PANCHATANTRA KI KAHANIYAN(DELUXE)             NaN
# ..             ...                                 ...             ...
# 776  9789387994133    PHYSICS NEET FOR EVERYONE PART 1        CP SINGH
# 777  9789387994140  PHYSICS NEET FOR EVERYONE : PART 2        CP SINGH
# 248  9789387997141                    ALL DOORS OPENED    INDER SHARMA
# 522  9789392565538       CHEIRO LANGUAGAGE OF THE HAND          CHEIRO
# 860  9798170112913     A PINCH OF SALT ROCKS AN EMPIRE            Mark
#
#                           Description  Leave
# 861               CHILDREN BOOK TRUST      1
# ...

# %%
dataset.sort_values('Employee Markme')
# Out:
#      Serial Number                           Company Name   Employee Markme  \
# 507  9789386126887  Aap kis rah par he safalta ya asfalta   Bhupender Singh
# 490  9788190514286                            MANTRA GYAN     "Che" Guevara
# 104  9788184821345                         BUDDHIST TALES     "Che" Guevara
# 445  9780747585893            A THOUSAND AD SPLENDID SUNS     "Che" Guevara
# 230  9789386900715             121 TEMarkLI RAMAN STORIES     "Che" Guevara
# ..             ...                                    ...               ...
# 866     8170115159             LAUT KE BUDDHU GHAR KO AYE               NaN
# 867     8189750232                     MarkITIK KAHANIYAN               NaN
# 868     8189750283                BANJARA HILL KE BACHCHE               NaN
# 869  9788170110445          STORIES FROM PANCHATANTRA III               NaN
# 943  9780007845811    COLLINS EASY LEARNING SPANISH DICT.               NaN
#
#               Description  Leave
# ...

# %%
dataset.sort_values('Employee Markme').head(6)
# Out:
#      Serial Number                           Company Name   Employee Markme  \
# 507  9789386126887  Aap kis rah par he safalta ya asfalta   Bhupender Singh
# 490  9788190514286                            MANTRA GYAN     "Che" Guevara
# 104  9788184821345                         BUDDHIST TALES     "Che" Guevara
# 445  9780747585893            A THOUSAND AD SPLENDID SUNS     "Che" Guevara
# 230  9789386900715             121 TEMarkLI RAMAN STORIES     "Che" Guevara
# 637  9789351215318                              PETER PAN     "Che" Guevara
#
#               Description  Leave
# 507  BLUE ROSE PUBLISHERS      1
# 490      BLUE BERRY BOOKS      0
# 104                   ACK      0
# 445           BLOOMS BURY      0
# 230      ALKA PUBLICATION      1
# 637    BPI INDIA PVT.LTD.      0

# %%
dataset.sort_values('Employee Markme', ascending=False).head(10)
# Out:
#      Serial Number                                       Company Name  \
# 114  9788189999322                                        BUDDHA[502]
# 443  9781408853306                      THE MAN WHO THOUGHT DIFFERENT
# 670  9789383186761                          ADVANCED VERBAL REASONING
# 258  9789381506974                                  I QUIT! NOW WHAT?
# 890  9789380200767  THE HAPPIOMarkIRE'S WAY  TO CREATE WEALTH IN A...
# 883  9789380200187                       INVEST THE HAPPIOMarkIRE WAY
# 294  9780099499480                            THE GODFATHER'S REVENGE
# 482  9781472520876                               THE SECOND WORLD WAR
# 426  9789385436284                  MACBETH BY SANDRA CLARK AND MASON
# 456  9789382563976                                      TWELFTH NIGHT
#
#         Employee Markme                 Description  Leave
# 114            s k rama                         ACK      0
# 443    karen blumenthal                 BLOOMS BURY      7
# ...

# %%
dataset.sort_values(['Serial Number','Employee Markme',], ascending=[1,0]).head(10)
# Out:
#      Serial Number                                       Company Name  \
# 861     8170110122                        PANCHATANTRA KI KAHANIYAN-1
# 862     8170110335                        PANCHATANTRA KI KAHANIYAN-2
# 863     8170110580                        PANCHATANTRA KI KAHANIYAN-3
# 864     8170110904                        PANCHATANTRA KI KAHANIYAN-4
# 865     8170112311                  PANCHATANTRA KI KAHANIYAN(DELUXE)
# 866     8170115159                         LAUT KE BUDDHU GHAR KO AYE
# 142     8174730257                                 ENGLISH LITERATURE
# 555     8176567523         COMPUTER FUNDAMENTALS  4TH REVISED EDITION
# 556     8176568155                      COMPUTERS MADE FRIENDLY VOL 5
# 557     8183331777  LET US C SOLUTIONS  9TH REV EDN (AS PER LET US...
#
#      Employee Markme          Description  Leave
# 861              NaN  CHILDREN BOOK TRUST      1
# 862              NaN  CHILDREN BOOK TRUST      1
# ...

# %% [markdown]
# # Making change in Data

# %%
dataset["total"] = 2*dataset["Leave"]

# %%
dataset.head(5)
# Out:
#    Serial Number               Company Name  Employee Markme  \
# 0  9788189999599             TALES OF SHIVA             Mark
# 1  9780099578079  1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2  9780198082897                   MY KUMAN             Mark
# 3  9780007880331    THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4  9780545060455           THE BLACK CIRCLE             Mark
#
#           Description  Leave  total
# 0                mark      0      0
# 1                Mark      0      0
# 2                Mark      0      0
# 3  4TH HARPER COLLINS      2      4
# 4  4TH HARPER COLLINS      0      0

# %%
dataset.drop(columns = ["total"])
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %%
dataset
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave  total
# 0                                  mark      0      0
# ...

# %%
dataset = dataset.drop(columns = ["total"])

# %%
dataset
# Out:
#      Serial Number                      Company Name  Employee Markme  \
# 0    9788189999599                    TALES OF SHIVA             Mark
# 1    9780099578079         1Q84 THE COMPLETE TRILOGY  HARUKI MURAKAMI
# 2    9780198082897                          MY KUMAN             Mark
# 3    9780007880331           THE GOD OF SMAAL THINGS    ARUNDHATI ROY
# 4    9780545060455                  THE BLACK CIRCLE             Mark
# ..             ...                               ...              ...
# 994  9788192778792  CURRENT AFFAIRS 49 PRACTICE SETS             Mark
# 995  9781862305274   BOY IN THE STRIPED PYJAMAS  THE      Boyne  John
# 996  9781730155116              SHRI KRISHMark LEELA             Mark
# 997  9789350891896                MENTAL MATHEMATICS             Mark
# 998  9789383182008            MATHEMATICS CLASS 10th      R.D. SHARMA
#
#                             Description  Leave
# 0                                  mark      0
# ...

# %% [markdown]
# # Saving Data(Exporting into desired format)

# %%
dataset.to_csv("modified1.csv")

# %%
dataset.to_csv("modified2.csv",index=False)

# %%
dataset,to_csv("modified.txt", index=False, sep='\t')
